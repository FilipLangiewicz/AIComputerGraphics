# %% [markdown]
# # Prepare the enviroment

# %%
LOCAL = False

# %%
if not LOCAL:
    import sys
    sys.path.insert(1, '/kaggle/input/datasets/dominikaboguszewska/sigk-p4-dragon-v1')

# %%
if not LOCAL:
    # !pip install trimesh
# Out:
# Collecting trimesh
#   Downloading trimesh-4.12.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.12/dist-packages (from trimesh) (2.0.2)
# Downloading trimesh-4.12.2-py3-none-any.whl (741 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 741.0/741.0 kB 25.5 MB/s eta 0:00:00
# Installing collected packages: trimesh
# Successfully installed trimesh-4.12.2

# %%
import os
import json
import trimesh
import datetime

import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split

from pathlib import Path

if LOCAL:
    from dragon.utils import load_mesh, pointcloud_to_mesh, visualize_transition, visualize_transition_3d, interpolate_pointclouds, standardize_pointcloud, load_mesh_pointcloud
    from dragon.model import DragonToTeapotVectorField, load_model
    from evaluate import evaluate_all
if not LOCAL:
    from utils import load_mesh, pointcloud_to_mesh, visualize_transition, visualize_transition_3d, interpolate_pointclouds, standardize_pointcloud, load_mesh_pointcloud
    from model import DragonToTeapotVectorField, load_model
    from evaluate import evaluate_all

# %%
def get_timestamp() -> str:
    ct = datetime.datetime.now()

    return ct.strftime("%Y-%m-%d_%H-%M-%S")

# %%
if LOCAL:
    PROJ_ROOT = Path(os.getcwd()).parents[0]

    MODELS_DIR = PROJ_ROOT / "modele"
    DRAGON_OBJECT_PATH = MODELS_DIR / "dragon_small.obj"
    TEAPOT_OBJECT_PATH = MODELS_DIR / "teapot.obj"

    DRAGON_PIPELINE_DIR = PROJ_ROOT / "dragon"
    RUNS_DIR = DRAGON_PIPELINE_DIR / "runs"
    RUNS_DIR.mkdir(parents=True, exist_ok=True)
else:
    PROJ_ROOT = Path("/kaggle/input/datasets/dominikaboguszewska/sigk-p4-dragon-v1")
    RUNS_DIR = Path("/kaggle/working/")

    DRAGON_OBJECT_PATH = PROJ_ROOT / "bunny.obj"
    TEAPOT_OBJECT_PATH = PROJ_ROOT / "teapot.obj"

CURRENT_RUN_DIR = RUNS_DIR / get_timestamp()
CURRENT_RUN_DIR.mkdir(parents=True, exist_ok=True)

CHECKPOINTS_DIR = CURRENT_RUN_DIR / "checkpoints"
CHECKPOINTS_DIR.mkdir(parents=True, exist_ok=True)

BEST_MODEL_PATH = CURRENT_RUN_DIR / "best_model.pt"

print(f"Project root: {PROJ_ROOT} (exists: {PROJ_ROOT.exists()}) \n")
print(f"Dragon object: {DRAGON_OBJECT_PATH} (exists: {DRAGON_OBJECT_PATH.exists()}) \n")
print(f"Teapot object: {TEAPOT_OBJECT_PATH} (exists: {TEAPOT_OBJECT_PATH.exists()}) \n")
print(f"Runs dir: {RUNS_DIR} (exists: {RUNS_DIR.exists()}) \n")
print(f"Current run dir: {CURRENT_RUN_DIR} (exists: {CURRENT_RUN_DIR.exists()}) \n")
print(f"Checkpoints dir: {CHECKPOINTS_DIR} (exists: {CHECKPOINTS_DIR.exists()}) \n")
# Out:
# Project root: /kaggle/input/datasets/dominikaboguszewska/sigk-p4-dragon-v1 (exists: True)
#
# Dragon object: /kaggle/input/datasets/dominikaboguszewska/sigk-p4-dragon-v1/bunny.obj (exists: True)
#
# Teapot object: /kaggle/input/datasets/dominikaboguszewska/sigk-p4-dragon-v1/teapot.obj (exists: True)
#
# Runs dir: /kaggle/working (exists: True)
#
# Current run dir: /kaggle/working/2026-05-12_16-04-48 (exists: True)
#
# Checkpoints dir: /kaggle/working/2026-05-12_16-04-48/checkpoints (exists: True)

# %%
N_POINTS = 2048
DATASET_SIZE = 10000

VAL_RATIO = 0.2

BATCH_SIZE = 16
NUM_WORKERS = 4

LOCAL_FEAT_DIMS = [64, 128]
CONTEXT_FEAT_DIMS = [256, 512]
HEAD_DIMS = [256, 128]
DROPOUT = 0.0

EPOCHS = 200
LR = 3e-4
CHECKPOINT = 5

# %%
config_path = Path(f"{CURRENT_RUN_DIR}/config.json")

config = {
    "n_points": N_POINTS,
    "dataset_size": DATASET_SIZE,
    "val_ratio": VAL_RATIO,
    "batch_size": BATCH_SIZE,
    "num_workers": NUM_WORKERS,
    "local_feat_dims": LOCAL_FEAT_DIMS,
    "context_feat_dims": CONTEXT_FEAT_DIMS,
    "head_dims": HEAD_DIMS,
    "dropout": DROPOUT,
    "epochs": EPOCHS,
    "learning_rate": LR,
    "checkpoint_interval": CHECKPOINT,
}

with open(config_path, "w") as f:
    json.dump(config, f, indent=4, sort_keys=True)

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

if DEVICE == "cuda":
    print(f"Using device: {DEVICE}")
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
else:
    raise RuntimeError("No GPU available!")
# Out:
# Using device: cuda
# GPU name: Tesla T4

# %%
device_t = torch.device(DEVICE)
print(f"Device for tensors: {device_t}")
# Out:
# Device for tensors: cuda

# %% [markdown]
# # Load the data

# %%
def generate_random_rotation() -> np.ndarray:
    q, _ = np.linalg.qr(np.random.randn(3, 3))

    if np.linalg.det(q) < 0:
        q[:, 0] *= -1

    return q.astype(np.float32)

# %%
def apply_random_scale(scale_bounds: tuple[float, float] = (0.7, 1.3)) -> float:
    return float(np.random.uniform(*scale_bounds))

# %%
class DragonTeapotDataset(Dataset):
    def __init__(
        self,
        dragon_path: str,
        teapot_path: str,
        n_points: int = 2048,
        dataset_size: int = 10000,
        use_augment: bool = True,
        scale_factor: tuple[float, float] = None,
    ):
        if scale_factor is None:
            scale_factor = (0.75, 1.25)

        self.n_points = n_points
        self.dataset_size = dataset_size
        self.use_augment = use_augment
        self.scale_factor = scale_factor

        self.dragon_mesh = load_mesh(dragon_path)
        self.teapot_target = standardize_pointcloud(
            load_mesh_pointcloud(teapot_path, n_points)
        )

    def __len__(self) -> int:
        return self.dataset_size

    def __getitem__(self, idx: int) -> tuple[torch.Tensor, torch.Tensor]:
        src_pts, _ = trimesh.sample.sample_surface(self.dragon_mesh, self.n_points)
        src_pts = standardize_pointcloud(src_pts.astype(np.float32))

        if self.use_augment:
            R = generate_random_rotation()
            s = apply_random_scale(self.scale_factor)
            src_pts = (src_pts @ R.T) * s

        return torch.from_numpy(src_pts), torch.from_numpy(self.teapot_target.copy())

# %%
dataset = DragonTeapotDataset(
    dragon_path=str(DRAGON_OBJECT_PATH),
    teapot_path=str(TEAPOT_OBJECT_PATH),
    n_points=N_POINTS,
    dataset_size=DATASET_SIZE,
    use_augment=True,
)

print(f"Dataset initialized with {len(dataset)} samples. Each sample has {N_POINTS} points")
# Out:
# Dataset initialized with 10000 samples. Each sample has 2048 points

# %%
source, target = dataset[0]
print(f"Source shape: {source.shape}")
print(f"Target shape: {target.shape}")
# Out:
# Source shape: torch.Size([2048, 3])
# Target shape: torch.Size([2048, 3])

# %%
val_size = int(len(dataset) * VAL_RATIO)
print(f"Validation set size: {val_size}")
# Out:
# Validation set size: 2000

# %%
train_dataset, val_dataset = random_split(dataset, [len(dataset) - val_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

print(f"Train set: {len(train_dataset)} samples, {len(train_loader)} batches")
print(f"Validation set: {len(val_dataset)} samples, {len(val_loader)} batches")
# Out:
# Train set: 8000 samples, 500 batches
# Validation set: 2000 samples, 125 batches

# %% [markdown]
# # Model

# %%
model = DragonToTeapotVectorField(
        local_feat_dims=LOCAL_FEAT_DIMS,
        context_feat_dims=CONTEXT_FEAT_DIMS,
        head_dims=HEAD_DIMS,
        dropout=DROPOUT,
    ).to(device_t)

print(f"Model initialized with {sum(p.numel() for p in model.parameters())} parameters.")
# Out:
# Model initialized with 373251 parameters.

# %% [markdown]
# # Training

# %%
optimizer = optim.Adam(model.parameters(), lr=LR)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS, eta_min=1e-6)

# %%
def chamfer_distance(pred: torch.Tensor, target: torch.Tensor) -> torch.Tensor:
    diff = pred.unsqueeze(2) - target.unsqueeze(1)
    dist_sq = (diff ** 2).sum(dim=-1)

    forward = dist_sq.min(dim=2).values.mean()
    backward = dist_sq.min(dim=1).values.mean()

    return forward + backward

# %%
print(f"Training DRAGON → TEAPOT for {EPOCHS} epochs …")

history: dict[str, list[float]] = {
    "train_loss": [],
    "val_loss": [],
    "lr": [],
}

best_val_loss = float("inf")

for epoch in range(1, EPOCHS + 1):
    model.train()
    train_losses = []

    for source, target in train_loader:
        source, target = source.to(device_t), target.to(device_t)

        loss = chamfer_distance(model(source), target)
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

        train_losses.append(loss.item())

    train_loss = float(np.mean(train_losses))
    history["train_loss"].append(train_loss)

    model.eval()
    val_losses = []

    for source, target in val_loader:
        source, target = source.to(device_t), target.to(device_t)

        loss = chamfer_distance(model(source), target)
        val_losses.append(loss.item())

    val_loss = float(np.mean(val_losses))
    history["val_loss"].append(val_loss)

    current_lr = optimizer.param_groups[0]["lr"]
    history["lr"].append(current_lr)

    scheduler.step()

    print(f"Epoch {epoch}/{EPOCHS}: Train Loss={train_loss:.6f}, Val Loss={val_loss:.6f}, LR={current_lr:.2e}")

    if epoch % CHECKPOINT == 0:
        checkpoint_path = CURRENT_RUN_DIR / f"checkpoint_{epoch}.pt"
        torch.save(model.state_dict(), checkpoint_path)
        print(f"    Saved checkpoint at epoch {epoch}")

    if val_loss < best_val_loss:
        torch.save(model.state_dict(), BEST_MODEL_PATH)
        print(f"    Saved best model at epoch {epoch}")

print("Training completed")
# Out:
# Training DRAGON → TEAPOT for 200 epochs …
# Epoch 1/200: Train Loss=0.030956, Val Loss=0.007873, LR=3.00e-04
#     Saved best model at epoch 1
# Epoch 2/200: Train Loss=0.006586, Val Loss=0.004673, LR=3.00e-04
#     Saved best model at epoch 2
# Epoch 3/200: Train Loss=0.004499, Val Loss=0.003694, LR=3.00e-04
#     Saved best model at epoch 3
# Epoch 4/200: Train Loss=0.003597, Val Loss=0.003161, LR=3.00e-04
#     Saved best model at epoch 4
# Epoch 5/200: Train Loss=0.003073, Val Loss=0.002798, LR=3.00e-04
#     Saved checkpoint at epoch 5
#     Saved best model at epoch 5
# Epoch 6/200: Train Loss=0.002749, Val Loss=0.002509, LR=3.00e-04
#     Saved best model at epoch 6
# Epoch 7/200: Train Loss=0.002521, Val Loss=0.002304, LR=2.99e-04
#     Saved best model at epoch 7
# Epoch 8/200: Train Loss=0.002342, Val Loss=0.002152, LR=2.99e-04
#     Saved best model at epoch 8
# Epoch 9/200: Train Loss=0.002196, Val Loss=0.002049, LR=2.99e-04
#     Saved best model at epoch 9
# Epoch 10/200: Train Loss=0.002094, Val Loss=0.001993, LR=2.99e-04
#     Saved checkpoint at epoch 10
#     Saved best model at epoch 10
# Epoch 11/200: Train Loss=0.002009, Val Loss=0.001966, LR=2.98e-04
#     Saved best model at epoch 11
# Epoch 12/200: Train Loss=0.001912, Val Loss=0.001874, LR=2.98e-04
#     Saved best model at epoch 12
# Epoch 13/200: Train Loss=0.001859, Val Loss=0.001766, LR=2.97e-04
#     Saved best model at epoch 13
# Epoch 14/200: Train Loss=0.001809, Val Loss=0.001724, LR=2.97e-04
#     Saved best model at epoch 14
# Epoch 15/200: Train Loss=0.001763, Val Loss=0.001694, LR=2.96e-04
#     Saved checkpoint at epoch 15
#     Saved best model at epoch 15
# Epoch 16/200: Train Loss=0.001733, Val Loss=0.001751, LR=2.96e-04
#     Saved best model at epoch 16
# Epoch 17/200: Train Loss=0.001710, Val Loss=0.001612, LR=2.95e-04
#     Saved best model at epoch 17
# Epoch 18/200: Train Loss=0.001672, Val Loss=0.001631, LR=2.95e-04
#     Saved best model at epoch 18
# Epoch 19/200: Train Loss=0.001647, Val Loss=0.001655, LR=2.94e-04
#     Saved best model at epoch 19
# Epoch 20/200: Train Loss=0.001624, Val Loss=0.001593, LR=2.93e-04
#     Saved checkpoint at epoch 20
#     Saved best model at epoch 20
# Epoch 21/200: Train Loss=0.001604, Val Loss=0.001566, LR=2.93e-04
#     Saved best model at epoch 21
# Epoch 22/200: Train Loss=0.001587, Val Loss=0.001596, LR=2.92e-04
#     Saved best model at epoch 22
# Epoch 23/200: Train Loss=0.001575, Val Loss=0.001556, LR=2.91e-04
#     Saved best model at epoch 23
# Epoch 24/200: Train Loss=0.001549, Val Loss=0.001547, LR=2.90e-04
#     Saved best model at epoch 24
# Epoch 25/200: Train Loss=0.001533, Val Loss=0.001479, LR=2.90e-04
#     Saved checkpoint at epoch 25
#     Saved best model at epoch 25
# Epoch 26/200: Train Loss=0.001524, Val Loss=0.001540, LR=2.89e-04
#     Saved best model at epoch 26
# Epoch 27/200: Train Loss=0.001517, Val Loss=0.001500, LR=2.88e-04
#     Saved best model at epoch 27
# Epoch 28/200: Train Loss=0.001499, Val Loss=0.001443, LR=2.87e-04
#     Saved best model at epoch 28
# Epoch 29/200: Train Loss=0.001489, Val Loss=0.001442, LR=2.86e-04
#     Saved best model at epoch 29
# Epoch 30/200: Train Loss=0.001474, Val Loss=0.001460, LR=2.85e-04
#     Saved checkpoint at epoch 30
#     Saved best model at epoch 30
# Epoch 31/200: Train Loss=0.001464, Val Loss=0.001434, LR=2.84e-04
#     Saved best model at epoch 31
# Epoch 32/200: Train Loss=0.001449, Val Loss=0.001413, LR=2.83e-04
#     Saved best model at epoch 32
# Epoch 33/200: Train Loss=0.001447, Val Loss=0.001412, LR=2.82e-04
#     Saved best model at epoch 33
# Epoch 34/200: Train Loss=0.001443, Val Loss=0.001409, LR=2.80e-04
#     Saved best model at epoch 34
# Epoch 35/200: Train Loss=0.001428, Val Loss=0.001401, LR=2.79e-04
#     Saved checkpoint at epoch 35
#     Saved best model at epoch 35
# Epoch 36/200: Train Loss=0.001421, Val Loss=0.001397, LR=2.78e-04
#     Saved best model at epoch 36
# Epoch 37/200: Train Loss=0.001413, Val Loss=0.001383, LR=2.77e-04
#     Saved best model at epoch 37
# Epoch 38/200: Train Loss=0.001407, Val Loss=0.001399, LR=2.75e-04
#     Saved best model at epoch 38
# Epoch 39/200: Train Loss=0.001399, Val Loss=0.001415, LR=2.74e-04
#     Saved best model at epoch 39
# Epoch 40/200: Train Loss=0.001391, Val Loss=0.001372, LR=2.73e-04
#     Saved checkpoint at epoch 40
#     Saved best model at epoch 40
# Epoch 41/200: Train Loss=0.001381, Val Loss=0.001376, LR=2.71e-04
#     Saved best model at epoch 41
# Epoch 42/200: Train Loss=0.001383, Val Loss=0.001359, LR=2.70e-04
#     Saved best model at epoch 42
# Epoch 43/200: Train Loss=0.001376, Val Loss=0.001348, LR=2.69e-04
#     Saved best model at epoch 43
# Epoch 44/200: Train Loss=0.001369, Val Loss=0.001382, LR=2.67e-04
#     Saved best model at epoch 44
# Epoch 45/200: Train Loss=0.001362, Val Loss=0.001352, LR=2.66e-04
#     Saved checkpoint at epoch 45
#     Saved best model at epoch 45
# Epoch 46/200: Train Loss=0.001354, Val Loss=0.001329, LR=2.64e-04
#     Saved best model at epoch 46
# Epoch 47/200: Train Loss=0.001349, Val Loss=0.001337, LR=2.63e-04
#     Saved best model at epoch 47
# Epoch 48/200: Train Loss=0.001346, Val Loss=0.001317, LR=2.61e-04
#     Saved best model at epoch 48
# Epoch 49/200: Train Loss=0.001342, Val Loss=0.001309, LR=2.59e-04
#     Saved best model at epoch 49
# Epoch 50/200: Train Loss=0.001341, Val Loss=0.001375, LR=2.58e-04
#     Saved checkpoint at epoch 50
#     Saved best model at epoch 50
# Epoch 51/200: Train Loss=0.001331, Val Loss=0.001309, LR=2.56e-04
#     Saved best model at epoch 51
# Epoch 52/200: Train Loss=0.001330, Val Loss=0.001290, LR=2.55e-04
#     Saved best model at epoch 52
# Epoch 53/200: Train Loss=0.001322, Val Loss=0.001280, LR=2.53e-04
#     Saved best model at epoch 53
# Epoch 54/200: Train Loss=0.001319, Val Loss=0.001289, LR=2.51e-04
#     Saved best model at epoch 54
# Epoch 55/200: Train Loss=0.001315, Val Loss=0.001295, LR=2.49e-04
#     Saved checkpoint at epoch 55
#     Saved best model at epoch 55
# Epoch 56/200: Train Loss=0.001311, Val Loss=0.001282, LR=2.48e-04
#     Saved best model at epoch 56
# Epoch 57/200: Train Loss=0.001311, Val Loss=0.001263, LR=2.46e-04
#     Saved best model at epoch 57
# Epoch 58/200: Train Loss=0.001302, Val Loss=0.001288, LR=2.44e-04
#     Saved best model at epoch 58
# Epoch 59/200: Train Loss=0.001298, Val Loss=0.001264, LR=2.42e-04
#     Saved best model at epoch 59
# Epoch 60/200: Train Loss=0.001298, Val Loss=0.001298, LR=2.40e-04
#     Saved checkpoint at epoch 60
#     Saved best model at epoch 60
# Epoch 61/200: Train Loss=0.001292, Val Loss=0.001266, LR=2.38e-04
#     Saved best model at epoch 61
# Epoch 62/200: Train Loss=0.001291, Val Loss=0.001267, LR=2.36e-04
#     Saved best model at epoch 62
# Epoch 63/200: Train Loss=0.001282, Val Loss=0.001249, LR=2.35e-04
#     Saved best model at epoch 63
# Epoch 64/200: Train Loss=0.001283, Val Loss=0.001245, LR=2.33e-04
#     Saved best model at epoch 64
# Epoch 65/200: Train Loss=0.001282, Val Loss=0.001241, LR=2.31e-04
#     Saved checkpoint at epoch 65
#     Saved best model at epoch 65
# Epoch 66/200: Train Loss=0.001281, Val Loss=0.001240, LR=2.29e-04
#     Saved best model at epoch 66
# Epoch 67/200: Train Loss=0.001272, Val Loss=0.001239, LR=2.27e-04
#     Saved best model at epoch 67
# Epoch 68/200: Train Loss=0.001269, Val Loss=0.001245, LR=2.25e-04
#     Saved best model at epoch 68
# Epoch 69/200: Train Loss=0.001267, Val Loss=0.001233, LR=2.23e-04
#     Saved best model at epoch 69
# Epoch 70/200: Train Loss=0.001270, Val Loss=0.001244, LR=2.20e-04
#     Saved checkpoint at epoch 70
#     Saved best model at epoch 70
# Epoch 71/200: Train Loss=0.001262, Val Loss=0.001236, LR=2.18e-04
#     Saved best model at epoch 71
# Epoch 72/200: Train Loss=0.001258, Val Loss=0.001224, LR=2.16e-04
#     Saved best model at epoch 72
# Epoch 73/200: Train Loss=0.001259, Val Loss=0.001227, LR=2.14e-04
#     Saved best model at epoch 73
# Epoch 74/200: Train Loss=0.001253, Val Loss=0.001222, LR=2.12e-04
#     Saved best model at epoch 74
# Epoch 75/200: Train Loss=0.001252, Val Loss=0.001228, LR=2.10e-04
#     Saved checkpoint at epoch 75
#     Saved best model at epoch 75
# Epoch 76/200: Train Loss=0.001251, Val Loss=0.001253, LR=2.08e-04
#     Saved best model at epoch 76
# Epoch 77/200: Train Loss=0.001246, Val Loss=0.001220, LR=2.06e-04
#     Saved best model at epoch 77
# Epoch 78/200: Train Loss=0.001244, Val Loss=0.001211, LR=2.03e-04
#     Saved best model at epoch 78
# Epoch 79/200: Train Loss=0.001241, Val Loss=0.001218, LR=2.01e-04
#     Saved best model at epoch 79
# Epoch 80/200: Train Loss=0.001240, Val Loss=0.001210, LR=1.99e-04
#     Saved checkpoint at epoch 80
#     Saved best model at epoch 80
# Epoch 81/200: Train Loss=0.001235, Val Loss=0.001216, LR=1.97e-04
#     Saved best model at epoch 81
# Epoch 82/200: Train Loss=0.001234, Val Loss=0.001195, LR=1.94e-04
#     Saved best model at epoch 82
# Epoch 83/200: Train Loss=0.001235, Val Loss=0.001187, LR=1.92e-04
#     Saved best model at epoch 83
# Epoch 84/200: Train Loss=0.001231, Val Loss=0.001208, LR=1.90e-04
#     Saved best model at epoch 84
# Epoch 85/200: Train Loss=0.001226, Val Loss=0.001192, LR=1.88e-04
#     Saved checkpoint at epoch 85
#     Saved best model at epoch 85
# Epoch 86/200: Train Loss=0.001230, Val Loss=0.001194, LR=1.85e-04
#     Saved best model at epoch 86
# Epoch 87/200: Train Loss=0.001225, Val Loss=0.001192, LR=1.83e-04
#     Saved best model at epoch 87
# Epoch 88/200: Train Loss=0.001222, Val Loss=0.001190, LR=1.81e-04
#     Saved best model at epoch 88
# Epoch 89/200: Train Loss=0.001221, Val Loss=0.001178, LR=1.79e-04
#     Saved best model at epoch 89
# Epoch 90/200: Train Loss=0.001217, Val Loss=0.001179, LR=1.76e-04
#     Saved checkpoint at epoch 90
#     Saved best model at epoch 90
# Epoch 91/200: Train Loss=0.001213, Val Loss=0.001174, LR=1.74e-04
#     Saved best model at epoch 91
# Epoch 92/200: Train Loss=0.001216, Val Loss=0.001175, LR=1.72e-04
#     Saved best model at epoch 92
# Epoch 93/200: Train Loss=0.001211, Val Loss=0.001184, LR=1.69e-04
#     Saved best model at epoch 93
# Epoch 94/200: Train Loss=0.001210, Val Loss=0.001171, LR=1.67e-04
#     Saved best model at epoch 94
# Epoch 95/200: Train Loss=0.001207, Val Loss=0.001168, LR=1.65e-04
#     Saved checkpoint at epoch 95
#     Saved best model at epoch 95
# Epoch 96/200: Train Loss=0.001205, Val Loss=0.001155, LR=1.62e-04
#     Saved best model at epoch 96
# Epoch 97/200: Train Loss=0.001202, Val Loss=0.001172, LR=1.60e-04
#     Saved best model at epoch 97
# Epoch 98/200: Train Loss=0.001202, Val Loss=0.001193, LR=1.58e-04
#     Saved best model at epoch 98
# Epoch 99/200: Train Loss=0.001202, Val Loss=0.001166, LR=1.55e-04
#     Saved best model at epoch 99
# Epoch 100/200: Train Loss=0.001197, Val Loss=0.001172, LR=1.53e-04
#     Saved checkpoint at epoch 100
#     Saved best model at epoch 100
# Epoch 101/200: Train Loss=0.001197, Val Loss=0.001173, LR=1.50e-04
#     Saved best model at epoch 101
# Epoch 102/200: Train Loss=0.001195, Val Loss=0.001157, LR=1.48e-04
#     Saved best model at epoch 102
# Epoch 103/200: Train Loss=0.001192, Val Loss=0.001160, LR=1.46e-04
#     Saved best model at epoch 103
# Epoch 104/200: Train Loss=0.001190, Val Loss=0.001165, LR=1.43e-04
#     Saved best model at epoch 104
# Epoch 105/200: Train Loss=0.001190, Val Loss=0.001162, LR=1.41e-04
#     Saved checkpoint at epoch 105
#     Saved best model at epoch 105
# Epoch 106/200: Train Loss=0.001185, Val Loss=0.001152, LR=1.39e-04
#     Saved best model at epoch 106
# Epoch 107/200: Train Loss=0.001186, Val Loss=0.001147, LR=1.36e-04
#     Saved best model at epoch 107
# Epoch 108/200: Train Loss=0.001183, Val Loss=0.001146, LR=1.34e-04
#     Saved best model at epoch 108
# Epoch 109/200: Train Loss=0.001185, Val Loss=0.001144, LR=1.32e-04
#     Saved best model at epoch 109
# Epoch 110/200: Train Loss=0.001180, Val Loss=0.001141, LR=1.29e-04
#     Saved checkpoint at epoch 110
#     Saved best model at epoch 110
# Epoch 111/200: Train Loss=0.001179, Val Loss=0.001146, LR=1.27e-04
#     Saved best model at epoch 111
# Epoch 112/200: Train Loss=0.001177, Val Loss=0.001139, LR=1.25e-04
#     Saved best model at epoch 112
# Epoch 113/200: Train Loss=0.001174, Val Loss=0.001133, LR=1.22e-04
#     Saved best model at epoch 113
# Epoch 114/200: Train Loss=0.001175, Val Loss=0.001148, LR=1.20e-04
#     Saved best model at epoch 114
# Epoch 115/200: Train Loss=0.001171, Val Loss=0.001132, LR=1.18e-04
#     Saved checkpoint at epoch 115
#     Saved best model at epoch 115
# Epoch 116/200: Train Loss=0.001172, Val Loss=0.001137, LR=1.16e-04
#     Saved best model at epoch 116
# Epoch 117/200: Train Loss=0.001168, Val Loss=0.001129, LR=1.13e-04
#     Saved best model at epoch 117
# Epoch 118/200: Train Loss=0.001168, Val Loss=0.001133, LR=1.11e-04
#     Saved best model at epoch 118
# Epoch 119/200: Train Loss=0.001167, Val Loss=0.001131, LR=1.09e-04
#     Saved best model at epoch 119
# Epoch 120/200: Train Loss=0.001167, Val Loss=0.001137, LR=1.07e-04
#     Saved checkpoint at epoch 120
#     Saved best model at epoch 120
# Epoch 121/200: Train Loss=0.001164, Val Loss=0.001131, LR=1.04e-04
#     Saved best model at epoch 121
# Epoch 122/200: Train Loss=0.001161, Val Loss=0.001124, LR=1.02e-04
#     Saved best model at epoch 122
# Epoch 123/200: Train Loss=0.001161, Val Loss=0.001138, LR=9.99e-05
#     Saved best model at epoch 123
# Epoch 124/200: Train Loss=0.001161, Val Loss=0.001117, LR=9.77e-05
#     Saved best model at epoch 124
# Epoch 125/200: Train Loss=0.001159, Val Loss=0.001115, LR=9.55e-05
#     Saved checkpoint at epoch 125
#     Saved best model at epoch 125
# Epoch 126/200: Train Loss=0.001159, Val Loss=0.001121, LR=9.33e-05
#     Saved best model at epoch 126
# Epoch 127/200: Train Loss=0.001154, Val Loss=0.001122, LR=9.11e-05
#     Saved best model at epoch 127
# Epoch 128/200: Train Loss=0.001156, Val Loss=0.001120, LR=8.90e-05
#     Saved best model at epoch 128
# Epoch 129/200: Train Loss=0.001154, Val Loss=0.001121, LR=8.68e-05
#     Saved best model at epoch 129
# Epoch 130/200: Train Loss=0.001156, Val Loss=0.001118, LR=8.47e-05
#     Saved checkpoint at epoch 130
#     Saved best model at epoch 130
# Epoch 131/200: Train Loss=0.001151, Val Loss=0.001112, LR=8.26e-05
#     Saved best model at epoch 131
# Epoch 132/200: Train Loss=0.001151, Val Loss=0.001112, LR=8.05e-05
#     Saved best model at epoch 132
# Epoch 133/200: Train Loss=0.001149, Val Loss=0.001133, LR=7.85e-05
#     Saved best model at epoch 133
# Epoch 134/200: Train Loss=0.001147, Val Loss=0.001115, LR=7.64e-05
#     Saved best model at epoch 134
# Epoch 135/200: Train Loss=0.001146, Val Loss=0.001114, LR=7.44e-05
#     Saved checkpoint at epoch 135
#     Saved best model at epoch 135
# Epoch 136/200: Train Loss=0.001145, Val Loss=0.001110, LR=7.24e-05
#     Saved best model at epoch 136
# Epoch 137/200: Train Loss=0.001144, Val Loss=0.001101, LR=7.04e-05
#     Saved best model at epoch 137
# Epoch 138/200: Train Loss=0.001144, Val Loss=0.001106, LR=6.84e-05
#     Saved best model at epoch 138
# Epoch 139/200: Train Loss=0.001144, Val Loss=0.001101, LR=6.65e-05
#     Saved best model at epoch 139
# Epoch 140/200: Train Loss=0.001142, Val Loss=0.001101, LR=6.45e-05
#     Saved checkpoint at epoch 140
#     Saved best model at epoch 140
# Epoch 141/200: Train Loss=0.001139, Val Loss=0.001096, LR=6.26e-05
#     Saved best model at epoch 141
# Epoch 142/200: Train Loss=0.001140, Val Loss=0.001100, LR=6.07e-05
#     Saved best model at epoch 142
# Epoch 143/200: Train Loss=0.001138, Val Loss=0.001108, LR=5.89e-05
#     Saved best model at epoch 143
# Epoch 144/200: Train Loss=0.001136, Val Loss=0.001103, LR=5.70e-05
#     Saved best model at epoch 144
# Epoch 145/200: Train Loss=0.001138, Val Loss=0.001095, LR=5.52e-05
#     Saved checkpoint at epoch 145
#     Saved best model at epoch 145
# Epoch 146/200: Train Loss=0.001137, Val Loss=0.001098, LR=5.34e-05
#     Saved best model at epoch 146
# Epoch 147/200: Train Loss=0.001136, Val Loss=0.001097, LR=5.16e-05
#     Saved best model at epoch 147
# Epoch 148/200: Train Loss=0.001132, Val Loss=0.001098, LR=4.99e-05
#     Saved best model at epoch 148
# Epoch 149/200: Train Loss=0.001132, Val Loss=0.001093, LR=4.82e-05
#     Saved best model at epoch 149
# Epoch 150/200: Train Loss=0.001132, Val Loss=0.001098, LR=4.65e-05
#     Saved checkpoint at epoch 150
#     Saved best model at epoch 150
# Epoch 151/200: Train Loss=0.001134, Val Loss=0.001088, LR=4.48e-05
#     Saved best model at epoch 151
# Epoch 152/200: Train Loss=0.001131, Val Loss=0.001095, LR=4.31e-05
#     Saved best model at epoch 152
# Epoch 153/200: Train Loss=0.001131, Val Loss=0.001092, LR=4.15e-05
#     Saved best model at epoch 153
# Epoch 154/200: Train Loss=0.001129, Val Loss=0.001088, LR=3.99e-05
#     Saved best model at epoch 154
# Epoch 155/200: Train Loss=0.001127, Val Loss=0.001087, LR=3.84e-05
#     Saved checkpoint at epoch 155
#     Saved best model at epoch 155
# Epoch 156/200: Train Loss=0.001128, Val Loss=0.001089, LR=3.68e-05
#     Saved best model at epoch 156
# Epoch 157/200: Train Loss=0.001128, Val Loss=0.001086, LR=3.53e-05
#     Saved best model at epoch 157
# Epoch 158/200: Train Loss=0.001126, Val Loss=0.001088, LR=3.38e-05
#     Saved best model at epoch 158
# Epoch 159/200: Train Loss=0.001125, Val Loss=0.001084, LR=3.24e-05
#     Saved best model at epoch 159
# Epoch 160/200: Train Loss=0.001125, Val Loss=0.001087, LR=3.09e-05
#     Saved checkpoint at epoch 160
#     Saved best model at epoch 160
# Epoch 161/200: Train Loss=0.001125, Val Loss=0.001087, LR=2.96e-05
#     Saved best model at epoch 161
# Epoch 162/200: Train Loss=0.001125, Val Loss=0.001086, LR=2.82e-05
#     Saved best model at epoch 162
# Epoch 163/200: Train Loss=0.001122, Val Loss=0.001084, LR=2.69e-05
#     Saved best model at epoch 163
# Epoch 164/200: Train Loss=0.001121, Val Loss=0.001079, LR=2.55e-05
#     Saved best model at epoch 164
# Epoch 165/200: Train Loss=0.001121, Val Loss=0.001080, LR=2.43e-05
#     Saved checkpoint at epoch 165
#     Saved best model at epoch 165
# Epoch 166/200: Train Loss=0.001123, Val Loss=0.001082, LR=2.30e-05
#     Saved best model at epoch 166
# Epoch 167/200: Train Loss=0.001119, Val Loss=0.001077, LR=2.18e-05
#     Saved best model at epoch 167
# Epoch 168/200: Train Loss=0.001119, Val Loss=0.001078, LR=2.06e-05
#     Saved best model at epoch 168
# Epoch 169/200: Train Loss=0.001118, Val Loss=0.001078, LR=1.95e-05
#     Saved best model at epoch 169
# Epoch 170/200: Train Loss=0.001119, Val Loss=0.001077, LR=1.84e-05
#     Saved checkpoint at epoch 170
#     Saved best model at epoch 170
# Epoch 171/200: Train Loss=0.001118, Val Loss=0.001079, LR=1.73e-05
#     Saved best model at epoch 171
# Epoch 172/200: Train Loss=0.001119, Val Loss=0.001079, LR=1.62e-05
#     Saved best model at epoch 172
# Epoch 173/200: Train Loss=0.001116, Val Loss=0.001078, LR=1.52e-05
#     Saved best model at epoch 173
# Epoch 174/200: Train Loss=0.001114, Val Loss=0.001074, LR=1.42e-05
#     Saved best model at epoch 174
# Epoch 175/200: Train Loss=0.001118, Val Loss=0.001078, LR=1.33e-05
#     Saved checkpoint at epoch 175
#     Saved best model at epoch 175
# Epoch 176/200: Train Loss=0.001115, Val Loss=0.001075, LR=1.24e-05
#     Saved best model at epoch 176
# Epoch 177/200: Train Loss=0.001114, Val Loss=0.001076, LR=1.15e-05
#     Saved best model at epoch 177
# Epoch 178/200: Train Loss=0.001115, Val Loss=0.001076, LR=1.07e-05
#     Saved best model at epoch 178
# Epoch 179/200: Train Loss=0.001114, Val Loss=0.001079, LR=9.84e-06
#     Saved best model at epoch 179
# Epoch 180/200: Train Loss=0.001114, Val Loss=0.001075, LR=9.06e-06
#     Saved checkpoint at epoch 180
#     Saved best model at epoch 180
# Epoch 181/200: Train Loss=0.001113, Val Loss=0.001072, LR=8.32e-06
#     Saved best model at epoch 181
# Epoch 182/200: Train Loss=0.001114, Val Loss=0.001072, LR=7.61e-06
#     Saved best model at epoch 182
# Epoch 183/200: Train Loss=0.001113, Val Loss=0.001075, LR=6.94e-06
#     Saved best model at epoch 183
# Epoch 184/200: Train Loss=0.001112, Val Loss=0.001074, LR=6.30e-06
#     Saved best model at epoch 184
# Epoch 185/200: Train Loss=0.001111, Val Loss=0.001074, LR=5.70e-06
#     Saved checkpoint at epoch 185
#     Saved best model at epoch 185
# Epoch 186/200: Train Loss=0.001112, Val Loss=0.001074, LR=5.13e-06
#     Saved best model at epoch 186
# Epoch 187/200: Train Loss=0.001112, Val Loss=0.001073, LR=4.60e-06
#     Saved best model at epoch 187
# Epoch 188/200: Train Loss=0.001111, Val Loss=0.001071, LR=4.11e-06
#     Saved best model at epoch 188
# Epoch 189/200: Train Loss=0.001110, Val Loss=0.001075, LR=3.65e-06
#     Saved best model at epoch 189
# Epoch 190/200: Train Loss=0.001110, Val Loss=0.001071, LR=3.23e-06
#     Saved checkpoint at epoch 190
#     Saved best model at epoch 190
# Epoch 191/200: Train Loss=0.001112, Val Loss=0.001071, LR=2.84e-06
#     Saved best model at epoch 191
# Epoch 192/200: Train Loss=0.001111, Val Loss=0.001071, LR=2.49e-06
#     Saved best model at epoch 192
# Epoch 193/200: Train Loss=0.001113, Val Loss=0.001074, LR=2.18e-06
#     Saved best model at epoch 193
# Epoch 194/200: Train Loss=0.001110, Val Loss=0.001071, LR=1.90e-06
#     Saved best model at epoch 194
# Epoch 195/200: Train Loss=0.001111, Val Loss=0.001073, LR=1.66e-06
#     Saved checkpoint at epoch 195
#     Saved best model at epoch 195
# Epoch 196/200: Train Loss=0.001109, Val Loss=0.001071, LR=1.46e-06
#     Saved best model at epoch 196
# Epoch 197/200: Train Loss=0.001111, Val Loss=0.001071, LR=1.30e-06
#     Saved best model at epoch 197
# Epoch 198/200: Train Loss=0.001110, Val Loss=0.001074, LR=1.17e-06
#     Saved best model at epoch 198
# Epoch 199/200: Train Loss=0.001110, Val Loss=0.001069, LR=1.07e-06
#     Saved best model at epoch 199
# Epoch 200/200: Train Loss=0.001110, Val Loss=0.001072, LR=1.02e-06
#     Saved checkpoint at epoch 200
#     Saved best model at epoch 200
# Training completed

# %%
history_path = Path(f"{CURRENT_RUN_DIR}/history.json")

with open(history_path, "w") as f:
    json.dump(history, f, indent=4, sort_keys=True)

# %%
plt.figure(figsize=(8, 5))
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{CURRENT_RUN_DIR}/loss.png", dpi=300, bbox_inches="tight")

# %%
start_epoch = 20

train_loss = history["train_loss"][start_epoch:]
val_loss = history["val_loss"][start_epoch:]

epochs = range(start_epoch, start_epoch + len(train_loss))

plt.figure(figsize=(8, 5))
plt.plot(epochs, train_loss, label="Train Loss")
plt.plot(epochs, val_loss, label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title(f"Training vs Validation Loss (from Epoch {start_epoch})")
plt.legend()
plt.grid(True)

plt.savefig(
    CURRENT_RUN_DIR / f"loss_from_epoch_{start_epoch}.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
plt.close()

# %%
plt.figure(figsize=(8, 5))
plt.plot(history["lr"], label="Learning Rate")
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.title("Learning Rate per Epoch")
plt.legend()
plt.grid(True)
plt.savefig(f"{CURRENT_RUN_DIR}/lr.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# # Evaluation

# %%
model = load_model(
    BEST_MODEL_PATH,
    local_feat_dims=LOCAL_FEAT_DIMS,
    context_feat_dims=CONTEXT_FEAT_DIMS,
    head_dims=HEAD_DIMS,
    dropout=DROPOUT,
    device=DEVICE
)

# %%
def normalize_pointcloud(points: np.ndarray) -> np.ndarray:
    points = points - points.mean(axis=0)
    scale = np.linalg.norm(points, axis=1).max()

    return points / scale

# %%
def transform_mesh(obj_path: Path, model, device, n_points: int) -> np.ndarray:
    pts = normalize_pointcloud(load_mesh_pointcloud(obj_path, n_points))
    tensor = torch.from_numpy(pts).unsqueeze(0).to(device)

    with torch.no_grad():
        pred = model(tensor).squeeze(0).cpu().numpy()

    return pred

# %%
model.eval()

teapot_mesh = load_mesh(TEAPOT_OBJECT_PATH)

pred_points = transform_mesh(DRAGON_OBJECT_PATH, model, DEVICE, N_POINTS)
pred_mesh = pointcloud_to_mesh(pred_points)

metrics = evaluate_all(pred_mesh, teapot_mesh, n_points=N_POINTS, resolution=64)
json.dump(metrics, open(CURRENT_RUN_DIR / "metrics.json", "w"), indent=4)

# %%
print("=== Dragon flow — metrics ===")
print(f"  IoU     : {metrics['iou']:.4f}")
print(f"  Dice    : {metrics['dice']:.4f}")
print(f"  Chamfer : {metrics['chamfer']:.6f}")
# Out:
# === Dragon flow — metrics ===
#   IoU     : 0.7974
#   Dice    : 0.8873
#   Chamfer : 3.209548

# %% [markdown]
# # Visualisation

# %%
model.eval()

src_pts = normalize_pointcloud(load_mesh_pointcloud(DRAGON_OBJECT_PATH, N_POINTS))
pred_pts = transform_mesh(DRAGON_OBJECT_PATH, model, DEVICE, N_POINTS)

steps = interpolate_pointclouds(src_pts, pred_pts, steps=4)

visualize_transition(
    steps,
    titles=["Dragon (input)", "Step 1", "Step 2", "Teapot (predicted)"]
)

# %%
visualize_transition_3d(
    steps,
    titles=["Dragon (input)", "Step 1", "Step 2", "Teapot (predicted)"]
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3b7e42f2-e9c7-4983-9f6b-465cc0f80e91" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b7e42f2-e9c7-4983-9f6b-465cc0f80e91")) {                    Plotly.newPlot(                        "3b7e42f2-e9c7-4983-9f6b-465cc0f80e91",                        [{"marker":{"color":[-0.5172818899154663,0.08296411484479904,0.4171757996082306,-0.3454502522945404,-0.1958112120628357,-0.5081016421318054,0.39453747868537903,0.5056411027908325,0.012729116715490818,0.5144163370132446,0.4812038838863373,-0.07668349146842957,0.31472671031951904,-0.16260360181331635,0.48514723777770996,0.5035141110420227,0.07495439052581787,0.0070489197969436646,0.3288632333278656,0.16681356728076935,0.38949841260910034,-0.5222969055175781,-0.0717785656452179,-0.23258842527866364,-0.026719823479652405,0.16219887137413025,0.09521970897912979,0.4738401174545288,0.5212068557739258,-0.3066539466381073,-0.04074688255786896,-0.007933754473924637,0.4945722222328186,-0.5015981793403625,0.4922824800014496,-0.13100284337997437,-0.691035807132721,-0.07557447254657745,-0.5486661791801453,-0.09943915158510208,0.24973993003368378,-0.5257970690727234,-0.40398988127708435,0.3496813178062439,0.3857261836528778,-0.7671932578086853,-0.1301659494638443,0.4820390045642853,0.2557760775089264,-0.0574420765042305,0.40000903606414795,0.42129164934158325,-0.015891827642917633,0.1517804116010666,0.13849835097789764,-0.6343474984169006,0.061507925391197205,0.10862157493829727,-0.05571381002664566,0.23461978137493134,-0.30214759707450867,-0.034233689308166504,-0.3770429193973541,0.42410916090011597,0.4749261438846588,-0.4071184992790222,-0.1399308145046234,-0.019769012928009033,-0.5085697174072266,-0.2875801622867584,-0.3735615611076355,-0.1722233146429062,-0.31604501605033875,-0.1991962492465973,0.3632422089576721,0.20795749127864838,-0.2286842316389084,0.5257525444030762,0.28365617990493774,0.08784408122301102,0.23067572712898254,0.013049233704805374,0.3308287560939789,0.11906903237104416,-0.488267183303833,-0.05321987718343735,-0.1342114508152008,0.46312761306762695,-0.22809264063835144,0.3653137683868408,-0.26491811871528625,-0.298717200756073,0.5127464532852173,-0.39864400029182434,0.2943761944770813,0.48435819149017334,-0.010867482051253319,0.4826008975505829,0.26127126812934875,0.0430607870221138,-0.22653064131736755,-0.5508212447166443,0.5078215599060059,0.31461989879608154,-0.13198624551296234,-0.47947514057159424,-0.09092602878808975,0.3886992931365967,0.48355555534362793,-0.35322651267051697,0.524362325668335,-0.2141759842634201,-0.31275373697280884,0.10800104588270187,0.19861707091331482,-0.14912737905979156,0.2912099361419678,0.024860620498657227,0.49027785658836365,0.3769703805446625,0.3740309476852417,-0.11523818224668503,0.31595176458358765,0.28626519441604614,0.3810352683067322,0.42755717039108276,0.350033700466156,-0.265354722738266,0.4872332513332367,-0.5256448984146118,0.0676359161734581,0.5171636939048767,0.504359245300293,-0.17749884724617004,0.44228509068489075,-0.25480952858924866,-0.33859261870384216,0.1556178480386734,-0.1373891979455948,0.27462512254714966,0.20712104439735413,-0.12759418785572052,-0.22782915830612183,-0.052940528839826584,0.11991073936223984,-0.25660786032676697,-0.4223226010799408,-0.1790589988231659,0.30636799335479736,0.517113208770752,-0.5920828580856323,-0.14849257469177246,0.5246617197990417,-0.5865105986595154,-0.29333406686782837,0.02113203890621662,-0.3037123680114746,-0.009917241521179676,0.5148192644119263,0.12489431351423264,-0.3003065288066864,0.49715933203697205,0.2790517210960388,-0.09771722555160522,-0.43233954906463623,0.17174282670021057,0.0803038477897644,0.33454248309135437,0.27860188484191895,0.49997809529304504,0.051197417 ...

# %% [markdown]
# # Download the results

# %%
import os
import subprocess
from IPython.display import FileLink, display

def download_file(path, download_file_name):
    os.chdir('/kaggle/working/')
    zip_name = f"/kaggle/working/{download_file_name}.zip"
    command = f"zip {zip_name} {path} -r"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)

    if result.returncode != 0:
        print("Unable to run zip command!")
        print(result.stderr)

        return

    display(FileLink(f'{download_file_name}.zip'))

# %%
if not LOCAL:
    download_file(CURRENT_RUN_DIR, f"SIGK_p4_dragon_{CURRENT_RUN_DIR.name}")
# Out:
# /kaggle/working/SIGK_p4_dragon_2026-05-12_16-04-48.zip
