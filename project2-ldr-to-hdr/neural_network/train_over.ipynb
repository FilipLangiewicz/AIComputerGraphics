# %%
import os, sys
from pathlib import Path

KAGGLE = os.path.exists("/kaggle/input")

if KAGGLE:
    sys.path.insert(0, "/kaggle/input/datasets/gpla77/project2-code")
    DATA_ROOT = Path("/kaggle/input/datasets/gpla77/hdr-patches/patches")
else:
    ROOT = Path(".").resolve()
    sys.path.insert(0, str(ROOT))
    DATA_ROOT = ROOT / "nn_data" / "patches"

print(f"Environment  : {'Kaggle' if KAGGLE else 'Local'}")
print(f"Train LDR    : {(DATA_ROOT / 'train' / 'ldr').exists()}")
print(f"Train under  : {(DATA_ROOT / 'train' / 'under').exists()}")
print(f"Train over   : {(DATA_ROOT / 'train' / 'over').exists()}")
print(f"Test LDR     : {(DATA_ROOT / 'test'  / 'ldr').exists()}")
# Out:
# Environment  : Kaggle
# Train LDR    : True
# Train under  : True
# Train over   : True
# Test LDR     : True

# %% [markdown]
# # Train over

# %%
from train import train

train(
    data_root      = DATA_ROOT,
    target         = "over",
    save_path      = Path("/kaggle/working/model_over.pth"),
    epochs         = 100,
    batch_size     = 8,
    lr             = 1e-4,
    alpha          = 0.8,
    features       = [32, 64, 128, 256],
    eval_every     = 5,
    num_workers    = 0,
    optimizer_name = "adam",
    scheduler_name = "plateau",
)
# Out:
# Device: cuda
# Train: 1400 samples | Test: 350 samples
# Params: 11,906,307
# Training:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Epoch 001/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 001/100  loss=0.1741  lr=1.00e-04
# Epoch 002/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 002/100  loss=0.1577  lr=1.00e-04
# Epoch 003/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 003/100  loss=0.1535  lr=1.00e-04
# Epoch 004/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 004/100  loss=0.1520  lr=1.00e-04
# Epoch 005/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 005/100  loss=0.1513  lr=1.00e-04
#   └─ eval  PSNR=23.96dB  (best=-infdB)
# Epoch 006/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 006/100  loss=0.1496  lr=1.00e-04
# Epoch 007/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 007/100  loss=0.1497  lr=1.00e-04
# Epoch 008/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 008/100  loss=0.1486  lr=1.00e-04
# Epoch 009/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 009/100  loss=0.1491  lr=1.00e-04
# Epoch 010/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 010/100  loss=0.1481  lr=1.00e-04
#   └─ eval  PSNR=23.91dB  (best=23.96dB)
# Epoch 011/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 011/100  loss=0.1489  lr=1.00e-04
# Epoch 012/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 012/100  loss=0.1475  lr=1.00e-04
# Epoch 013/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 013/100  loss=0.1470  lr=1.00e-04
# Epoch 014/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 014/100  loss=0.1463  lr=1.00e-04
# Epoch 015/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 015/100  loss=0.1466  lr=1.00e-04
#   └─ eval  PSNR=24.39dB  (best=23.96dB)
# Epoch 016/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 016/100  loss=0.1466  lr=1.00e-04
# Epoch 017/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 017/100  loss=0.1460  lr=1.00e-04
# Epoch 018/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 018/100  loss=0.1461  lr=1.00e-04
# Epoch 019/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 019/100  loss=0.1457  lr=1.00e-04
# Epoch 020/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 020/100  loss=0.1462  lr=1.00e-04
#   └─ eval  PSNR=24.50dB  (best=24.39dB)
# Epoch 021/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 021/100  loss=0.1458  lr=1.00e-04
# Epoch 022/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 022/100  loss=0.1453  lr=1.00e-04
# Epoch 023/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 023/100  loss=0.1446  lr=1.00e-04
# Epoch 024/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 024/100  loss=0.1443  lr=1.00e-04
# Epoch 025/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 025/100  loss=0.1442  lr=1.00e-04
#   └─ eval  PSNR=24.66dB  (best=24.50dB)
# Epoch 026/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 026/100  loss=0.1446  lr=1.00e-04
# Epoch 027/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 027/100  loss=0.1437  lr=1.00e-04
# Epoch 028/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 028/100  loss=0.1439  lr=1.00e-04
# Epoch 029/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 029/100  loss=0.1436  lr=1.00e-04
# Epoch 030/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 030/100  loss=0.1430  lr=1.00e-04
#   └─ eval  PSNR=24.42dB  (best=24.66dB)
# Epoch 031/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 031/100  loss=0.1432  lr=1.00e-04
# Epoch 032/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 032/100  loss=0.1430  lr=1.00e-04
# Epoch 033/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 033/100  loss=0.1425  lr=1.00e-04
# Epoch 034/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 034/100  loss=0.1418  lr=1.00e-04
# Epoch 035/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 035/100  loss=0.1420  lr=1.00e-04
#   └─ eval  PSNR=24.69dB  (best=24.66dB)
# Epoch 036/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 036/100  loss=0.1404  lr=1.00e-04
# Epoch 037/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 037/100  loss=0.1401  lr=1.00e-04
# Epoch 038/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 038/100  loss=0.1396  lr=1.00e-04
# Epoch 039/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 039/100  loss=0.1392  lr=1.00e-04
# Epoch 040/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 040/100  loss=0.1387  lr=1.00e-04
#   └─ eval  PSNR=24.36dB  (best=24.69dB)
# Epoch 041/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 041/100  loss=0.1382  lr=1.00e-04
# Epoch 042/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 042/100  loss=0.1375  lr=1.00e-04
# Epoch 043/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 043/100  loss=0.1368  lr=1.00e-04
# Epoch 044/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 044/100  loss=0.1357  lr=1.00e-04
# Epoch 045/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 045/100  loss=0.1357  lr=1.00e-04
#   └─ eval  PSNR=24.81dB  (best=24.69dB)
# Epoch 046/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 046/100  loss=0.1351  lr=1.00e-04
# Epoch 047/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 047/100  loss=0.1337  lr=1.00e-04
# Epoch 048/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 048/100  loss=0.1325  lr=1.00e-04
# Epoch 049/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 049/100  loss=0.1322  lr=1.00e-04
# Epoch 050/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 050/100  loss=0.1315  lr=1.00e-04
#   └─ eval  PSNR=23.86dB  (best=24.81dB)
# Epoch 051/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 051/100  loss=0.1297  lr=1.00e-04
# Epoch 052/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 052/100  loss=0.1294  lr=1.00e-04
# Epoch 053/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 053/100  loss=0.1291  lr=1.00e-04
# Epoch 054/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 054/100  loss=0.1270  lr=1.00e-04
# Epoch 055/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 055/100  loss=0.1252  lr=1.00e-04
#   └─ eval  PSNR=24.02dB  (best=24.81dB)
# Epoch 056/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 056/100  loss=0.1263  lr=1.00e-04
# Epoch 057/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 057/100  loss=0.1237  lr=1.00e-04
# Epoch 058/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 058/100  loss=0.1231  lr=1.00e-04
# Epoch 059/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 059/100  loss=0.1226  lr=1.00e-04
# Epoch 060/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 060/100  loss=0.1207  lr=1.00e-04
#   └─ eval  PSNR=24.31dB  (best=24.81dB)
# Epoch 061/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 061/100  loss=0.1204  lr=1.00e-04
# Epoch 062/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 062/100  loss=0.1200  lr=1.00e-04
# Epoch 063/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 063/100  loss=0.1200  lr=1.00e-04
# Epoch 064/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 064/100  loss=0.1187  lr=1.00e-04
# Epoch 065/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 065/100  loss=0.1168  lr=1.00e-04
#   └─ eval  PSNR=24.18dB  (best=24.81dB)
# Epoch 066/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 066/100  loss=0.1163  lr=1.00e-04
# Epoch 067/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 067/100  loss=0.1154  lr=1.00e-04
# Epoch 068/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 068/100  loss=0.1145  lr=1.00e-04
# Epoch 069/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 069/100  loss=0.1139  lr=1.00e-04
# Epoch 070/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 070/100  loss=0.1138  lr=1.00e-04
#   └─ eval  PSNR=24.24dB  (best=24.81dB)
# Epoch 071/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 071/100  loss=0.1130  lr=1.00e-04
# Epoch 072/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 072/100  loss=0.1131  lr=1.00e-04
# Epoch 073/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 073/100  loss=0.1112  lr=1.00e-04
# Epoch 074/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 074/100  loss=0.1105  lr=1.00e-04
# Epoch 075/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 075/100  loss=0.1109  lr=1.00e-04
#   └─ eval  PSNR=24.29dB  (best=24.81dB)
# Epoch 076/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 076/100  loss=0.1093  lr=1.00e-04
# Epoch 077/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 077/100  loss=0.1084  lr=1.00e-04
# Epoch 078/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 078/100  loss=0.1076  lr=1.00e-04
# Epoch 079/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 079/100  loss=0.1080  lr=1.00e-04
# Epoch 080/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 080/100  loss=0.1077  lr=1.00e-04
#   └─ eval  PSNR=23.99dB  (best=24.81dB)
# Epoch 081/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 081/100  loss=0.1073  lr=1.00e-04
# Epoch 082/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 082/100  loss=0.1071  lr=1.00e-04
# Epoch 083/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 083/100  loss=0.1054  lr=1.00e-04
# Epoch 084/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 084/100  loss=0.1046  lr=1.00e-04
# Epoch 085/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 085/100  loss=0.1047  lr=1.00e-04
#   └─ eval  PSNR=23.93dB  (best=24.81dB)
# Epoch 086/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 086/100  loss=0.1036  lr=1.00e-04
# Epoch 087/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 087/100  loss=0.1030  lr=1.00e-04
# Epoch 088/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 088/100  loss=0.1032  lr=1.00e-04
# Epoch 089/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 089/100  loss=0.1029  lr=1.00e-04
# Epoch 090/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 090/100  loss=0.1011  lr=1.00e-04
#   └─ eval  PSNR=23.81dB  (best=24.81dB)
# Epoch 091/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 091/100  loss=0.1017  lr=1.00e-04
# Epoch 092/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 092/100  loss=0.1007  lr=1.00e-04
# Epoch 093/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 093/100  loss=0.1002  lr=1.00e-04
# Epoch 094/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 094/100  loss=0.0992  lr=1.00e-04
# Epoch 095/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 095/100  loss=0.0991  lr=1.00e-04
#   └─ eval  PSNR=23.72dB  (best=24.81dB)
# Epoch 096/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 096/100  loss=0.0990  lr=1.00e-04
# Epoch 097/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 097/100  loss=0.0980  lr=1.00e-04
# Epoch 098/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 098/100  loss=0.0982  lr=1.00e-04
# Epoch 099/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 099/100  loss=0.0976  lr=1.00e-04
# Epoch 100/100:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 100/100  loss=0.0967  lr=1.00e-04
#   └─ eval  PSNR=24.12dB  (best=24.81dB)
#
# Done. Best PSNR: 24.81dB → /kaggle/working/model_over.pth
