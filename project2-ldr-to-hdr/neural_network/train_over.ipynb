# %%
import os, sys
from pathlib import Path

KAGGLE = os.path.exists("/kaggle/input")

if KAGGLE:
    sys.path.insert(0, "/kaggle/input/datasets/gpla77/project2-code")
    DATA_ROOT = Path("/kaggle/input/datasets/gpla77/hdr-patches/patches")
else:
    ROOT = Path(".").resolve()
    sys.path.insert(0, str(ROOT))
    DATA_ROOT = ROOT / "nn_data" / "patches"

print(f"Environment  : {'Kaggle' if KAGGLE else 'Local'}")
print(f"Train LDR    : {(DATA_ROOT / 'train' / 'ldr').exists()}")
print(f"Train under  : {(DATA_ROOT / 'train' / 'under').exists()}")
print(f"Train over   : {(DATA_ROOT / 'train' / 'over').exists()}")
print(f"Test LDR     : {(DATA_ROOT / 'test'  / 'ldr').exists()}")
# Out:
# Environment  : Kaggle
# Train LDR    : True
# Train under  : True
# Train over   : True
# Test LDR     : True

# %% [markdown]
# # Train over

# %%
from train import train

train(
    data_root      = DATA_ROOT,
    target         = "over",
    save_path      = Path("/kaggle/working/model_over.pth"),
    epochs         = 200,
    batch_size     = 8,
    lr             = 1e-4,
    alpha          = 0.8,
    features       = [32, 64, 128, 256],
    eval_every     = 3,
    num_workers    = 0,
    optimizer_name = "adam",
    scheduler_name = "cosine",
)
# Out:
# Device: cuda
# Train: 1400 samples | Test: 350 samples
# Params: 11,906,307
# Training:   0%|          | 0/200 [00:00<?, ?epoch/s]
# Epoch 001/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 001/200  loss=0.1806  lr=1.00e-04
# Epoch 002/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 002/200  loss=0.1566  lr=1.00e-04
# Epoch 003/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 003/200  loss=0.1532  lr=1.00e-04
#   └─ saved best checkpoint
#   └─ eval  PSNR=23.46dB  (best=23.46dB)
# Epoch 004/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 004/200  loss=0.1512  lr=9.99e-05
# Epoch 005/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 005/200  loss=0.1505  lr=9.99e-05
# Epoch 006/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 006/200  loss=0.1505  lr=9.98e-05
#   └─ saved best checkpoint
#   └─ eval  PSNR=23.95dB  (best=23.95dB)
# Epoch 007/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 007/200  loss=0.1494  lr=9.98e-05
# Epoch 008/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 008/200  loss=0.1489  lr=9.97e-05
# Epoch 009/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 009/200  loss=0.1484  lr=9.96e-05
#   └─ saved best checkpoint
#   └─ eval  PSNR=24.15dB  (best=24.15dB)
# Epoch 010/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 010/200  loss=0.1477  lr=9.95e-05
# Epoch 011/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 011/200  loss=0.1480  lr=9.94e-05
# Epoch 012/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 012/200  loss=0.1476  lr=9.93e-05
#   └─ eval  PSNR=24.01dB  (best=24.15dB)
# Epoch 013/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 013/200  loss=0.1476  lr=9.91e-05
# Epoch 014/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 014/200  loss=0.1466  lr=9.90e-05
# Epoch 015/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 015/200  loss=0.1461  lr=9.88e-05
#   └─ saved best checkpoint
#   └─ eval  PSNR=24.17dB  (best=24.17dB)
# Epoch 016/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 016/200  loss=0.1467  lr=9.86e-05
# Epoch 017/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 017/200  loss=0.1468  lr=9.84e-05
# Epoch 018/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 018/200  loss=0.1462  lr=9.82e-05
#   └─ saved best checkpoint
#   └─ eval  PSNR=24.45dB  (best=24.45dB)
# Epoch 019/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 019/200  loss=0.1465  lr=9.80e-05
# Epoch 020/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 020/200  loss=0.1459  lr=9.78e-05
# Epoch 021/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 021/200  loss=0.1447  lr=9.76e-05
#   └─ saved best checkpoint
#   └─ eval  PSNR=24.46dB  (best=24.46dB)
# Epoch 022/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 022/200  loss=0.1451  lr=9.73e-05
# Epoch 023/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 023/200  loss=0.1452  lr=9.70e-05
# Epoch 024/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 024/200  loss=0.1449  lr=9.68e-05
#   └─ eval  PSNR=24.45dB  (best=24.46dB)
# Epoch 025/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 025/200  loss=0.1444  lr=9.65e-05
# Epoch 026/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 026/200  loss=0.1439  lr=9.62e-05
# Epoch 027/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 027/200  loss=0.1440  lr=9.59e-05
#   └─ eval  PSNR=24.37dB  (best=24.46dB)
# Epoch 028/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 028/200  loss=0.1438  lr=9.56e-05
# Epoch 029/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 029/200  loss=0.1428  lr=9.52e-05
# Epoch 030/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 030/200  loss=0.1435  lr=9.49e-05
#   └─ saved best checkpoint
#   └─ eval  PSNR=24.69dB  (best=24.69dB)
# Epoch 031/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 031/200  loss=0.1430  lr=9.46e-05
# Epoch 032/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 032/200  loss=0.1425  lr=9.42e-05
# Epoch 033/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 033/200  loss=0.1422  lr=9.38e-05
#   └─ saved best checkpoint
#   └─ eval  PSNR=24.70dB  (best=24.70dB)
# Epoch 034/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 034/200  loss=0.1408  lr=9.34e-05
# Epoch 035/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 035/200  loss=0.1406  lr=9.30e-05
# Epoch 036/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 036/200  loss=0.1397  lr=9.26e-05
#   └─ eval  PSNR=24.33dB  (best=24.70dB)
# Epoch 037/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 037/200  loss=0.1392  lr=9.22e-05
# Epoch 038/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 038/200  loss=0.1385  lr=9.18e-05
# Epoch 039/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 039/200  loss=0.1377  lr=9.14e-05
#   └─ eval  PSNR=24.48dB  (best=24.70dB)
# Epoch 040/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 040/200  loss=0.1365  lr=9.09e-05
# Epoch 041/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 041/200  loss=0.1361  lr=9.05e-05
# Epoch 042/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 042/200  loss=0.1340  lr=9.00e-05
#   └─ eval  PSNR=24.27dB  (best=24.70dB)
# Epoch 043/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 043/200  loss=0.1350  lr=8.95e-05
# Epoch 044/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 044/200  loss=0.1331  lr=8.90e-05
# Epoch 045/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 045/200  loss=0.1317  lr=8.85e-05
#   └─ eval  PSNR=24.44dB  (best=24.70dB)
# Epoch 046/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 046/200  loss=0.1313  lr=8.80e-05
# Epoch 047/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 047/200  loss=0.1307  lr=8.75e-05
# Epoch 048/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 048/200  loss=0.1292  lr=8.70e-05
#   └─ eval  PSNR=24.36dB  (best=24.70dB)
# Epoch 049/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 049/200  loss=0.1288  lr=8.64e-05
# Epoch 050/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 050/200  loss=0.1275  lr=8.59e-05
# Epoch 051/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 051/200  loss=0.1271  lr=8.54e-05
#   └─ eval  PSNR=24.17dB  (best=24.70dB)
# Epoch 052/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 052/200  loss=0.1257  lr=8.48e-05
# Epoch 053/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 053/200  loss=0.1255  lr=8.42e-05
# Epoch 054/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 054/200  loss=0.1236  lr=8.37e-05
#   └─ eval  PSNR=24.27dB  (best=24.70dB)
# Epoch 055/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 055/200  loss=0.1229  lr=8.31e-05
# Epoch 056/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 056/200  loss=0.1229  lr=8.25e-05
# Epoch 057/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 057/200  loss=0.1214  lr=8.19e-05
#   └─ eval  PSNR=24.42dB  (best=24.70dB)
# Epoch 058/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 058/200  loss=0.1215  lr=8.13e-05
# Epoch 059/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 059/200  loss=0.1201  lr=8.06e-05
# Epoch 060/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 060/200  loss=0.1193  lr=8.00e-05
#   └─ eval  PSNR=24.29dB  (best=24.70dB)
# Epoch 061/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 061/200  loss=0.1191  lr=7.94e-05
# Epoch 062/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 062/200  loss=0.1184  lr=7.88e-05
# Epoch 063/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 063/200  loss=0.1163  lr=7.81e-05
#   └─ eval  PSNR=24.28dB  (best=24.70dB)
# Epoch 064/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 064/200  loss=0.1161  lr=7.75e-05
# Epoch 065/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 065/200  loss=0.1158  lr=7.68e-05
# Epoch 066/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 066/200  loss=0.1151  lr=7.61e-05
#   └─ eval  PSNR=24.15dB  (best=24.70dB)
# Epoch 067/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 067/200  loss=0.1137  lr=7.55e-05
# Epoch 068/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 068/200  loss=0.1130  lr=7.48e-05
# Epoch 069/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 069/200  loss=0.1134  lr=7.41e-05
#   └─ eval  PSNR=24.34dB  (best=24.70dB)
# Epoch 070/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 070/200  loss=0.1122  lr=7.34e-05
# Epoch 071/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 071/200  loss=0.1107  lr=7.27e-05
# Epoch 072/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 072/200  loss=0.1104  lr=7.20e-05
#   └─ eval  PSNR=24.13dB  (best=24.70dB)
# Epoch 073/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 073/200  loss=0.1103  lr=7.13e-05
# Epoch 074/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 074/200  loss=0.1086  lr=7.06e-05
# Epoch 075/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 075/200  loss=0.1084  lr=6.99e-05
#   └─ eval  PSNR=23.87dB  (best=24.70dB)
# Epoch 076/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 076/200  loss=0.1081  lr=6.91e-05
# Epoch 077/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 077/200  loss=0.1071  lr=6.84e-05
# Epoch 078/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 078/200  loss=0.1067  lr=6.77e-05
#   └─ eval  PSNR=24.03dB  (best=24.70dB)
# Epoch 079/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 079/200  loss=0.1054  lr=6.69e-05
# Epoch 080/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 080/200  loss=0.1053  lr=6.62e-05
# Epoch 081/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 081/200  loss=0.1052  lr=6.55e-05
#   └─ eval  PSNR=23.81dB  (best=24.70dB)
# Epoch 082/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 082/200  loss=0.1040  lr=6.47e-05
# Epoch 083/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 083/200  loss=0.1036  lr=6.39e-05
# Epoch 084/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 084/200  loss=0.1031  lr=6.32e-05
#   └─ eval  PSNR=24.00dB  (best=24.70dB)
# Epoch 085/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 085/200  loss=0.1034  lr=6.24e-05
# Epoch 086/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 086/200  loss=0.1017  lr=6.17e-05
# Epoch 087/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 087/200  loss=0.1019  lr=6.09e-05
#   └─ eval  PSNR=24.00dB  (best=24.70dB)
# Epoch 088/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 088/200  loss=0.1009  lr=6.01e-05
# Epoch 089/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 089/200  loss=0.1013  lr=5.94e-05
# Epoch 090/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 090/200  loss=0.1003  lr=5.86e-05
#   └─ eval  PSNR=24.17dB  (best=24.70dB)
# Epoch 091/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 091/200  loss=0.0999  lr=5.78e-05
# Epoch 092/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 092/200  loss=0.0993  lr=5.70e-05
# Epoch 093/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 093/200  loss=0.0989  lr=5.63e-05
#   └─ eval  PSNR=24.25dB  (best=24.70dB)
# Epoch 094/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 094/200  loss=0.0986  lr=5.55e-05
# Epoch 095/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 095/200  loss=0.0978  lr=5.47e-05
# Epoch 096/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 096/200  loss=0.0980  lr=5.39e-05
#   └─ eval  PSNR=24.20dB  (best=24.70dB)
# Epoch 097/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 097/200  loss=0.0971  lr=5.31e-05
# Epoch 098/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 098/200  loss=0.0962  lr=5.24e-05
# Epoch 099/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 099/200  loss=0.0961  lr=5.16e-05
#   └─ eval  PSNR=24.24dB  (best=24.70dB)
# Epoch 100/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 100/200  loss=0.0959  lr=5.08e-05
# Epoch 101/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 101/200  loss=0.0951  lr=5.00e-05
# Epoch 102/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 102/200  loss=0.0957  lr=4.92e-05
#   └─ eval  PSNR=24.12dB  (best=24.70dB)
# Epoch 103/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 103/200  loss=0.0946  lr=4.84e-05
# Epoch 104/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 104/200  loss=0.0939  lr=4.76e-05
# Epoch 105/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 105/200  loss=0.0937  lr=4.69e-05
#   └─ eval  PSNR=23.96dB  (best=24.70dB)
# Epoch 106/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 106/200  loss=0.0930  lr=4.61e-05
# Epoch 107/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 107/200  loss=0.0923  lr=4.53e-05
# Epoch 108/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 108/200  loss=0.0936  lr=4.45e-05
#   └─ eval  PSNR=24.24dB  (best=24.70dB)
# Epoch 109/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 109/200  loss=0.0929  lr=4.37e-05
# Epoch 110/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 110/200  loss=0.0920  lr=4.30e-05
# Epoch 111/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 111/200  loss=0.0919  lr=4.22e-05
#   └─ eval  PSNR=24.04dB  (best=24.70dB)
# Epoch 112/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 112/200  loss=0.0913  lr=4.14e-05
# Epoch 113/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 113/200  loss=0.0910  lr=4.06e-05
# Epoch 114/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 114/200  loss=0.0904  lr=3.99e-05
#   └─ eval  PSNR=24.28dB  (best=24.70dB)
# Epoch 115/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 115/200  loss=0.0899  lr=3.91e-05
# Epoch 116/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 116/200  loss=0.0902  lr=3.83e-05
# Epoch 117/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 117/200  loss=0.0895  lr=3.76e-05
#   └─ eval  PSNR=24.22dB  (best=24.70dB)
# Epoch 118/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 118/200  loss=0.0891  lr=3.68e-05
# Epoch 119/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 119/200  loss=0.0887  lr=3.61e-05
# Epoch 120/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 120/200  loss=0.0885  lr=3.53e-05
#   └─ eval  PSNR=24.25dB  (best=24.70dB)
# Epoch 121/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 121/200  loss=0.0885  lr=3.45e-05
# Epoch 122/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 122/200  loss=0.0879  lr=3.38e-05
# Epoch 123/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 123/200  loss=0.0877  lr=3.31e-05
#   └─ eval  PSNR=24.36dB  (best=24.70dB)
# Epoch 124/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 124/200  loss=0.0878  lr=3.23e-05
# Epoch 125/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 125/200  loss=0.0872  lr=3.16e-05
# Epoch 126/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 126/200  loss=0.0869  lr=3.09e-05
#   └─ eval  PSNR=24.25dB  (best=24.70dB)
# Epoch 127/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 127/200  loss=0.0865  lr=3.01e-05
# Epoch 128/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 128/200  loss=0.0865  lr=2.94e-05
# Epoch 129/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 129/200  loss=0.0857  lr=2.87e-05
#   └─ eval  PSNR=24.22dB  (best=24.70dB)
# Epoch 130/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 130/200  loss=0.0861  lr=2.80e-05
# Epoch 131/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 131/200  loss=0.0855  lr=2.73e-05
# Epoch 132/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 132/200  loss=0.0852  lr=2.66e-05
#   └─ eval  PSNR=24.14dB  (best=24.70dB)
# Epoch 133/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 133/200  loss=0.0852  lr=2.59e-05
# Epoch 134/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 134/200  loss=0.0852  lr=2.52e-05
# Epoch 135/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 135/200  loss=0.0846  lr=2.45e-05
#   └─ eval  PSNR=24.17dB  (best=24.70dB)
# Epoch 136/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 136/200  loss=0.0841  lr=2.39e-05
# Epoch 137/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 137/200  loss=0.0846  lr=2.32e-05
# Epoch 138/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 138/200  loss=0.0842  lr=2.25e-05
#   └─ eval  PSNR=24.06dB  (best=24.70dB)
# Epoch 139/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 139/200  loss=0.0836  lr=2.19e-05
# Epoch 140/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 140/200  loss=0.0837  lr=2.12e-05
# Epoch 141/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 141/200  loss=0.0833  lr=2.06e-05
#   └─ eval  PSNR=23.99dB  (best=24.70dB)
# Epoch 142/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 142/200  loss=0.0829  lr=2.00e-05
# Epoch 143/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 143/200  loss=0.0828  lr=1.94e-05
# Epoch 144/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 144/200  loss=0.0826  lr=1.87e-05
#   └─ eval  PSNR=24.26dB  (best=24.70dB)
# Epoch 145/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 145/200  loss=0.0826  lr=1.81e-05
# Epoch 146/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 146/200  loss=0.0824  lr=1.75e-05
# Epoch 147/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 147/200  loss=0.0820  lr=1.69e-05
#   └─ eval  PSNR=24.10dB  (best=24.70dB)
# Epoch 148/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 148/200  loss=0.0821  lr=1.63e-05
# Epoch 149/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 149/200  loss=0.0819  lr=1.58e-05
# Epoch 150/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 150/200  loss=0.0817  lr=1.52e-05
#   └─ eval  PSNR=24.02dB  (best=24.70dB)
# Epoch 151/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 151/200  loss=0.0814  lr=1.46e-05
# Epoch 152/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 152/200  loss=0.0811  lr=1.41e-05
# Epoch 153/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 153/200  loss=0.0809  lr=1.36e-05
#   └─ eval  PSNR=24.05dB  (best=24.70dB)
# Epoch 154/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 154/200  loss=0.0812  lr=1.30e-05
# Epoch 155/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 155/200  loss=0.0810  lr=1.25e-05
# Epoch 156/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 156/200  loss=0.0807  lr=1.20e-05
#   └─ eval  PSNR=23.98dB  (best=24.70dB)
# Epoch 157/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 157/200  loss=0.0805  lr=1.15e-05
# Epoch 158/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 158/200  loss=0.0806  lr=1.10e-05
# Epoch 159/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 159/200  loss=0.0803  lr=1.05e-05
#   └─ eval  PSNR=24.01dB  (best=24.70dB)
# Epoch 160/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 160/200  loss=0.0803  lr=1.00e-05
# Epoch 161/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 161/200  loss=0.0803  lr=9.55e-06
# Epoch 162/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 162/200  loss=0.0800  lr=9.09e-06
#   └─ eval  PSNR=24.10dB  (best=24.70dB)
# Epoch 163/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 163/200  loss=0.0799  lr=8.65e-06
# Epoch 164/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 164/200  loss=0.0798  lr=8.21e-06
# Epoch 165/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 165/200  loss=0.0796  lr=7.78e-06
#   └─ eval  PSNR=24.04dB  (best=24.70dB)
# Epoch 166/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 166/200  loss=0.0797  lr=7.37e-06
# Epoch 167/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 167/200  loss=0.0795  lr=6.96e-06
# Epoch 168/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 168/200  loss=0.0795  lr=6.57e-06
#   └─ eval  PSNR=24.14dB  (best=24.70dB)
# Epoch 169/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 169/200  loss=0.0794  lr=6.18e-06
# Epoch 170/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 170/200  loss=0.0791  lr=5.81e-06
# Epoch 171/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 171/200  loss=0.0793  lr=5.45e-06
#   └─ eval  PSNR=24.04dB  (best=24.70dB)
# Epoch 172/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 172/200  loss=0.0792  lr=5.10e-06
# Epoch 173/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 173/200  loss=0.0790  lr=4.76e-06
# Epoch 174/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 174/200  loss=0.0788  lr=4.43e-06
#   └─ eval  PSNR=24.04dB  (best=24.70dB)
# Epoch 175/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 175/200  loss=0.0789  lr=4.11e-06
# Epoch 176/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 176/200  loss=0.0789  lr=3.81e-06
# Epoch 177/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 177/200  loss=0.0789  lr=3.51e-06
#   └─ eval  PSNR=24.01dB  (best=24.70dB)
# Epoch 178/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 178/200  loss=0.0788  lr=3.23e-06
# Epoch 179/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 179/200  loss=0.0787  lr=2.96e-06
# Epoch 180/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 180/200  loss=0.0785  lr=2.70e-06
#   └─ eval  PSNR=24.07dB  (best=24.70dB)
# Epoch 181/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 181/200  loss=0.0787  lr=2.45e-06
# Epoch 182/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 182/200  loss=0.0784  lr=2.21e-06
# Epoch 183/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 183/200  loss=0.0783  lr=1.99e-06
#   └─ eval  PSNR=24.09dB  (best=24.70dB)
# Epoch 184/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 184/200  loss=0.0785  lr=1.77e-06
# Epoch 185/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 185/200  loss=0.0786  lr=1.57e-06
# Epoch 186/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 186/200  loss=0.0784  lr=1.38e-06
#   └─ eval  PSNR=24.06dB  (best=24.70dB)
# Epoch 187/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 187/200  loss=0.0781  lr=1.20e-06
# Epoch 188/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 188/200  loss=0.0783  lr=1.04e-06
# Epoch 189/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 189/200  loss=0.0783  lr=8.86e-07
#   └─ eval  PSNR=24.10dB  (best=24.70dB)
# Epoch 190/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 190/200  loss=0.0785  lr=7.45e-07
# Epoch 191/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 191/200  loss=0.0782  lr=6.16e-07
# Epoch 192/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 192/200  loss=0.0782  lr=4.99e-07
#   └─ eval  PSNR=24.09dB  (best=24.70dB)
# Epoch 193/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 193/200  loss=0.0782  lr=3.94e-07
# Epoch 194/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 194/200  loss=0.0783  lr=3.02e-07
# Epoch 195/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 195/200  loss=0.0783  lr=2.22e-07
#   └─ eval  PSNR=24.03dB  (best=24.70dB)
# Epoch 196/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 196/200  loss=0.0782  lr=1.54e-07
# Epoch 197/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 197/200  loss=0.0786  lr=9.87e-08
# Epoch 198/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 198/200  loss=0.0782  lr=5.55e-08
#   └─ eval  PSNR=24.04dB  (best=24.70dB)
# Epoch 199/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 199/200  loss=0.0783  lr=2.47e-08
# Epoch 200/200:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 200/200  loss=0.0781  lr=6.17e-09
#   └─ eval  PSNR=24.09dB  (best=24.70dB)
#
# Done. Best PSNR: 24.70dB → /kaggle/working/model_over.pth
