# %%
import os, sys
from pathlib import Path

KAGGLE = os.path.exists("/kaggle/input")

if KAGGLE:
    sys.path.insert(0, "/kaggle/input/datasets/gpla77/project2-code")
    DATA_ROOT = Path("/kaggle/input/datasets/gpla77/hdr-patches/patches")
else:
    ROOT = Path(".").resolve()
    sys.path.insert(0, str(ROOT))
    DATA_ROOT = ROOT / "nn_data" / "patches"

print(f"Environment  : {'Kaggle' if KAGGLE else 'Local'}")
print(f"Train LDR    : {(DATA_ROOT / 'train' / 'ldr').exists()}")
print(f"Train under  : {(DATA_ROOT / 'train' / 'under').exists()}")
print(f"Train over   : {(DATA_ROOT / 'train' / 'over').exists()}")
print(f"Test LDR     : {(DATA_ROOT / 'test'  / 'ldr').exists()}")
# Out:
# Environment  : Kaggle
# Train LDR    : True
# Train under  : True
# Train over   : True
# Test LDR     : True

# %% [markdown]
# # Train under

# %%
from train import train

train(
    data_root      = DATA_ROOT,
    target         = "over",
    save_path      = Path("/kaggle/working/model_over.pth"),
    epochs         = 10,
    batch_size     = 8,
    lr             = 1e-4,
    alpha          = 0.8,
    features       = [32, 64, 128, 256],
    eval_every     = 1,
    num_workers    = 0,
    optimizer_name = "adam",
    scheduler_name = "plateau",
)
# Out:
# Device: cuda
# Train: 1400 samples | Test: 350 samples
# Params: 11,906,307
# Training:   0%|          | 0/10 [00:00<?, ?epoch/s]
# Epoch 001/10:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 001/10  loss=0.1753  lr=1.00e-04
#   └─ eval  PSNR=22.99dB  (best=-infdB)
# Epoch 002/10:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 002/10  loss=0.1576  lr=1.00e-04
#   └─ eval  PSNR=23.50dB  (best=22.99dB)
# Epoch 003/10:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 003/10  loss=0.1548  lr=1.00e-04
#   └─ eval  PSNR=23.71dB  (best=23.50dB)
# Epoch 004/10:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 004/10  loss=0.1515  lr=1.00e-04
#   └─ eval  PSNR=23.84dB  (best=23.71dB)
# Epoch 005/10:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 005/10  loss=0.1507  lr=1.00e-04
#   └─ eval  PSNR=23.92dB  (best=23.84dB)
# Epoch 006/10:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 006/10  loss=0.1503  lr=1.00e-04
#   └─ eval  PSNR=24.01dB  (best=23.92dB)
# Epoch 007/10:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 007/10  loss=0.1492  lr=1.00e-04
#   └─ eval  PSNR=23.81dB  (best=24.01dB)
# Epoch 008/10:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 008/10  loss=0.1481  lr=1.00e-04
#   └─ eval  PSNR=23.79dB  (best=24.01dB)
# Epoch 009/10:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 009/10  loss=0.1486  lr=1.00e-04
#   └─ eval  PSNR=24.38dB  (best=24.01dB)
# Epoch 010/10:   0%|          | 0/175 [00:00<?, ?batch/s]
# Epoch 010/10  loss=0.1485  lr=1.00e-04
#   └─ eval  PSNR=24.24dB  (best=24.38dB)
#
# Done. Best PSNR: 24.38dB → /kaggle/working/model_over.pth
