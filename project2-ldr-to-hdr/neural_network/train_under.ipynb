# %%
import os, sys
from pathlib import Path

KAGGLE = os.path.exists("/kaggle/input")

if KAGGLE:
    sys.path.insert(0, "/kaggle/input/project2-code/neural_network")
    sys.path.insert(0, "/kaggle/input/project2-code")
    SELECTED_DIR = Path("/kaggle/input/hdr-eye-selected/selected")
else:
    ROOT = Path(".").resolve()
    sys.path.insert(0, str(ROOT))
    SELECTED_DIR = ROOT / "nn_data" / "selected"

LDR_DIR   = SELECTED_DIR / "LDR"
UNDER_DIR = SELECTED_DIR / "Bracketed_images-27"

print(f"Environment : {'Kaggle' if KAGGLE else 'Local'}")
print(f"LDR exists  : {LDR_DIR.exists()}")
print(f"Under exists: {UNDER_DIR.exists()}")
# Out:
# Environment : Local
# LDR exists  : True
# Under exists: True
